# %%
# Way To Long Words 
num_words = int(input()) # Number of words are entered 
for i in range (num_words):
    word = input().strip()
    if len (word)>10: print(f"{word[0]}{len(word)-2}{word[-1]}") #هنقوم باخذ اول حرف من الكلمة واخر حرف عندي لو هي اعلي من 10 حروف 
    # ثم نقوم بطرح العدد الكلي من 2 
    #example ==> internationlization (20 words) ==> [first] [centeri(20-8)][final[n] 
    #output = i18n
    else :print(word)
# Out:
# word
# l10n
# i13n
# p43s
